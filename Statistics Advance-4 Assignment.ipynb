# %%
from PIL import Image
from IPython.display import display

img = Image.open('Screenshot 2024-09-08 013847.png')
img1 = Image.open('Screenshot 2024-09-08 014118.png')
img2 = Image.open('Screenshot 2024-09-08 014317.png')
img3 = Image.open('Screenshot 2024-09-08 014521.png')
img4 = Image.open('Screenshot 2024-09-08 014728.png')

# %%
Q1: What is the difference between a t-test and a z-test? Provide an example scenario where you would use each type of test.

t-test: Used when the sample size is small (typically 
𝑛<30) or when the population standard deviation is unknown. It accounts for the additional variability that arises from estimating the population standard deviation from the sample.
Example: Testing whether the mean weight of a group of 15 participants differs from a known population mean.
z-test: Used when the sample size is large (typically 
𝑛≥30) and the population standard deviation is known. It assumes that the sample means are normally distributed.
Example: Testing whether the average score of 100 students is significantly different from a national average score, assuming the population standard deviation is known.

# %%
Q2: Differentiate between one-tailed and two-tailed tests.

One-tailed test: Tests for a deviation in a specific direction (either greater than or less than a specified value).
Example: Testing if a new drug improves recovery time (you only care if it’s shorter, not longer).
Two-tailed test: Tests for a deviation in both directions (either greater or less than a specified value).
Example: Testing if a new teaching method leads to a significant difference in exam scores compared to the standard method, regardless of whether the scores go up or down.

# %%
Q3: Explain the concept of Type 1 and Type 2 errors in hypothesis testing. Provide an example scenario for each type of error.

Type 1 error: Rejecting the null hypothesis when it is actually true (false positive).
Example: A medical test indicating that a patient has a disease when they do not (false positive diagnosis).
Type 2 error: Failing to reject the null hypothesis when it is actually false (false negative).
Example: A medical test failing to detect a disease in a patient who actually has it (false negative).

# %%
Q4: Explain Bayes's theorem with an example.

Bayes' theorem describes the probability of an event based on prior knowledge of related conditions. It’s represented as:

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=249x79>

# %%
Example: A medical test is 95% accurate for detecting a rare disease (1% population prevalence). Bayes' theorem can calculate the probability that a person who tested positive actually has the disease, accounting for the test's accuracy and the disease's rarity.

# %%
Q5: What is a confidence interval? How to calculate the confidence interval, explain with an example.

A confidence interval (CI) is a range of values, derived from a sample, within which we expect the population parameter (e.g., mean) to lie. It’s calculated as:

# %%
img1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=673x191>

# %%
Q6: Use Bayes' Theorem to calculate the probability of an event occurring given prior knowledge of the event's probability and new evidence. Provide a sample problem and solution.

Problem: A test for a disease is 99% accurate (i.e., true positive rate), and the disease affects 0.1% of the population. What is the probability a person has the disease if they test positive?

# %%
img2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=877x239>

# %%
Q7: Calculate the 95% confidence interval for a sample of data with a mean of 50 and a standard deviation of 5. Interpret the results.

For a sample size n, and assuming normality, the 95% CI is calculated as:

# %%
img3
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=708x236>

# %%
Q8: What is the margin of error in a confidence interval? How does sample size affect the margin of error?

The margin of error (MoE) is the amount added/subtracted to the sample mean to form the confidence interval. It is calculated as:

# %%
img4
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=689x192>

# %%
Q9: Calculate the z-score for a data point with a value of 75, a population mean of 70, and a population standard deviation of 5.

The z-score is calculated as:

z= x−μ / σ = 75−70 / 5 =1

Interpretation: The data point is 1 standard deviation above the population mean.

# %%
Q10: Conduct a hypothesis test on the effectiveness of a weight loss drug (given details in the question).
Null hypothesis: 𝐻0 : The drug has no significant effect.
Alternative hypothesis: 𝐻1 The drug has a significant effect.
t-statistic:
